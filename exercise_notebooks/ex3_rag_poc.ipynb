# %%
import os
import dotenv

dotenv.load_dotenv()

if not os.getenv("GITHUB_TOKEN"):
    raise ValueError("GITHUB_TOKEN environment variable is not set.")

os.environ["OPENAI_API_KEY"] = os.getenv("GITHUB_TOKEN")
os.environ["OPENAI_BASE_URL"] = "https://models.inference.ai.azure.com"

# %%
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, StorageContext, load_index_from_storage
from llama_index.core import Settings

llm = OpenAI(
    model="gpt-4o-mini",
    api_key=os.getenv("GITHUB_TOKEN"),
    api_base=os.getenv("OPENAI_BASE_URL"),
)

embed_model = OpenAIEmbedding(
    model="text-embedding-3-small",
    api_key=os.getenv("GITHUB_TOKEN"),
    api_base=os.getenv("OPENAI_BASE_URL"), 
)

Settings.llm = llm
Settings.embed_model = embed_model

# %%
# # Tuning chunking parameters for better performance
# Settings.chunk_size = 50
# Settings.chunk_overlap = 5

# %%
try:
    storage_context = StorageContext.from_defaults(
        persist_dir="../data/local_index"
        )
    index= load_index_from_storage(storage_context)
except:
    documents = SimpleDirectoryReader("../data").load_data()
    index = VectorStoreIndex.from_documents(documents, insert_batch_size=150)
    index.storage_context.persist(persist_dir="../data/local_index")
# Out:
# 2026-02-12 18:45:11,075 - INFO - Loading all indices.

# %%
query_engine = index.as_query_engine()

# %%
query_engine.query("Who is Deadpool?")
# Out:
# 2026-02-12 18:45:11,675 - INFO - HTTP Request: POST https://models.inference.ai.azure.com/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 18:45:15,186 - INFO - HTTP Request: POST https://models.inference.ai.azure.com/chat/completions "HTTP/1.1 200 OK"
# Response(response='Deadpool, whose real name is Wade Winston Wilson, is a character known for his extreme regenerative healing factor, which grants him near-immortality. He was a former Canadian Special Forces operative and mercenary who volunteered for the Weapon X program after being diagnosed with terminal cancer. The experiment cured his cancer but left him disfigured and mentally unstable. Deadpool is a master assassin skilled in various combat forms and weaponry, particularly katanas and firearms. He is recognized for his unique "Fourth Wall" awareness, allowing him to interact with the audience and comment on narrative elements. His personality is marked by chaotic humor, which serves as a coping mechanism for his psychological struggles. He has complex relationships, including a tumultuous family background, a marriage to Shiklah, and connections with characters like Cable, Spider-Man, and Wolverine. Although he often operates alone, he has been part of groups like X-Force and the Avengers.', source_nodes=[NodeWithScore(node=TextNode(id_='56558bdb-73b4-473d-b0e6-1a3dda704f59', embedding=None, metadata={'file_path': 'c:\\Users\\Roninasaurus\\Documents\\Mayur_Learning\\Lambton\\SoftwareTools_Akshey\\aml3303\\exercise_notebooks\\..\\data\\Deadpool_KB.txt', 'file_name': 'Deadpool_KB.txt', 'file_type': 'text/plain', 'file_size': 2512, 'creation_date': '2026-02-06', 'last_modified_date': '2026-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='4284b05d-3a1a-4ed9-994c-c10ff38b3fed', node_type='4', metadata={'file_path': 'c:\\Users\\Roninasaurus\\Documents\\Mayur_Learning\\Lambton\\SoftwareTools_Akshey\\aml3303\\exercise_notebooks\\..\\data\\Deadpool_KB.txt', 'file_name': 'Deadpool_KB.txt', 'file_type': 'text/plain', 'file_size': 2512, 'creation_date': '2026-02-06', 'last_modified_date': '2026-02-06'}, hash='e41ffc6eb90f0b6c520e1f7169a76535663c95a11f07a772be2219de20bb769f')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Character Name: Wade Winston Wilson\r\nAlias: Deadpool, The Merc with a Mouth, Regeneratin\' Degenerate\r\nFirst Appearance: The New Mutants #98 (February 1991)\r\n\r\nOrigins & History:\r\nA former Canadian Special Forces operative and mercenary, Wade Wilson was diagnosed with terminal cancer. He volunteered for the clandestine Weapon X program, which subjected him to a rogue regenerative healing factor derived from Wolverine. The experiment cured his cancer but left him severely disfigured with a perpetually healing, scarred visage and a severely unstable mental state, a side effect of his healing factor constantly fighting brain damage.\r\n\r\nDefining Traits & Abilities:\r\nPossesses an extreme regenerative healing factor that makes him virtually immortal, capable of regenerating from near disintegration. He is a master assassin and mercenary, proficient in multiple forms of combat and weaponry, with a particular affinity for katanas and firearms. His most famous trait is his "Fourth Wall" awareness; he knows he is a comic book/film character, directly addressing the reader/viewer and commenting on narrative tropes. This meta-awareness is intertwined with a chaotic, irreverent, and hyper-verbal sense of humor used to mask deep psychological pain. He is morally ambiguous, operating as an antihero.\r\n\r\nPersonal Details:\r\nAge: Chronologically born in the 1970s (appears ageless due to healing factor).\r\nFamily: Has a tumultuous relationship with his father, who was abusive. He is married to the supernatural entity Shiklah, Queen of the Monster Metropolis, though their relationship is complicated and often separated. He has a daughter named Eleanor, from a non-romantic genetic legacy, whom he protect ...

# %%
query_engine.query("Is Deadpool single?")
# Out:
# 2026-02-12 18:45:15,492 - INFO - HTTP Request: POST https://models.inference.ai.azure.com/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 18:45:16,504 - INFO - HTTP Request: POST https://models.inference.ai.azure.com/chat/completions "HTTP/1.1 200 OK"
# Response(response='Deadpool is not single; he is married to Shiklah, the Queen of the Monster Metropolis. However, their relationship is complicated and often sees them separated.', source_nodes=[NodeWithScore(node=TextNode(id_='56558bdb-73b4-473d-b0e6-1a3dda704f59', embedding=None, metadata={'file_path': 'c:\\Users\\Roninasaurus\\Documents\\Mayur_Learning\\Lambton\\SoftwareTools_Akshey\\aml3303\\exercise_notebooks\\..\\data\\Deadpool_KB.txt', 'file_name': 'Deadpool_KB.txt', 'file_type': 'text/plain', 'file_size': 2512, 'creation_date': '2026-02-06', 'last_modified_date': '2026-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='4284b05d-3a1a-4ed9-994c-c10ff38b3fed', node_type='4', metadata={'file_path': 'c:\\Users\\Roninasaurus\\Documents\\Mayur_Learning\\Lambton\\SoftwareTools_Akshey\\aml3303\\exercise_notebooks\\..\\data\\Deadpool_KB.txt', 'file_name': 'Deadpool_KB.txt', 'file_type': 'text/plain', 'file_size': 2512, 'creation_date': '2026-02-06', 'last_modified_date': '2026-02-06'}, hash='e41ffc6eb90f0b6c520e1f7169a76535663c95a11f07a772be2219de20bb769f')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Character Name: Wade Winston Wilson\r\nAlias: Deadpool, The Merc with a Mouth, Regeneratin\' Degenerate\r\nFirst Appearance: The New Mutants #98 (February 1991)\r\n\r\nOrigins & History:\r\nA former Canadian Special Forces operative and mercenary, Wade Wilson was diagnosed with terminal cancer. He volunteered for the clandestine Weapon X program, which subjected him to a rogue regenerative healing factor derived from Wolverine. The experiment cured his cancer but left him severely disfigured with a perpetually healing, scarred visage and a severely unstable mental state, a side effect of his healing factor constantly fighting brain damage.\r\n\r\nDefining Traits & Abilities:\r\nPossesses an extreme regenerative healing factor that makes him virtually immortal, capable of regenerating from near disintegration. He is a master assassin and mercenary, proficient in multiple forms of combat and weaponry, with a particular affinity for katanas and firearms. His most famous trait is his "Fourth Wall" awareness; he knows he is a comic book/film character, directly addressing the reader/viewer and commenting on narrative tropes. This meta-awareness is intertwined with a chaotic, irreverent, and hyper-verbal sense of humor used to mask deep psychological pain. He is morally ambiguous, operating as an antihero.\r\n\r\nPersonal Details:\r\nAge: Chronologically born in the 1970s (appears ageless due to healing factor).\r\nFamily: Has a tumultuous relationship with his father, who was abusive. He is married to the supernatural entity Shiklah, Queen of the Monster Metropolis, though their relationship is complicated and often separated. He has a daughter named Eleanor, from a non-romantic genetic legacy, whom he protects fiercely.\r\nKey Relationships: Often a reluctant ally to Cable (Nathan Summers), whom he views as a brother/father figure. Has a frenemy dynamic with Spider-Man and Wolverine. His frequent chauffeur and confidant is the mundane cab driver Dopinder.\r\nBase of Operations: Mobile, but often operates out of a run-down apartment in New York City.\r\nAffiliation: Primarily a loner, but has been a member of X-Force, the Avengers, and the Mercs for Money.\r\n\r\nPsychological Profile: Diagnosed with severe mental illness, including psychosis and manic tendencies, exacerbated by his meta-awareness. His rapid-fire humor is a coping mechanism for trauma, disfigurement, and existential ennui. Despite his violent profession, he adheres to a personal (if flexible) code that often protects innocents and children.', mimetype='text/pla ...

# %%
query_engine.query("How old is Deadpool?")
# Out:
# 2026-02-12 18:45:16,614 - INFO - HTTP Request: POST https://models.inference.ai.azure.com/embeddings "HTTP/1.1 200 OK"
# 2026-02-12 18:45:17,504 - INFO - HTTP Request: POST https://models.inference.ai.azure.com/chat/completions "HTTP/1.1 200 OK"
# Response(response='Deadpool is chronologically born in the 1970s but appears ageless due to his regenerative healing factor.', source_nodes=[NodeWithScore(node=TextNode(id_='56558bdb-73b4-473d-b0e6-1a3dda704f59', embedding=None, metadata={'file_path': 'c:\\Users\\Roninasaurus\\Documents\\Mayur_Learning\\Lambton\\SoftwareTools_Akshey\\aml3303\\exercise_notebooks\\..\\data\\Deadpool_KB.txt', 'file_name': 'Deadpool_KB.txt', 'file_type': 'text/plain', 'file_size': 2512, 'creation_date': '2026-02-06', 'last_modified_date': '2026-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='4284b05d-3a1a-4ed9-994c-c10ff38b3fed', node_type='4', metadata={'file_path': 'c:\\Users\\Roninasaurus\\Documents\\Mayur_Learning\\Lambton\\SoftwareTools_Akshey\\aml3303\\exercise_notebooks\\..\\data\\Deadpool_KB.txt', 'file_name': 'Deadpool_KB.txt', 'file_type': 'text/plain', 'file_size': 2512, 'creation_date': '2026-02-06', 'last_modified_date': '2026-02-06'}, hash='e41ffc6eb90f0b6c520e1f7169a76535663c95a11f07a772be2219de20bb769f')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Character Name: Wade Winston Wilson\r\nAlias: Deadpool, The Merc with a Mouth, Regeneratin\' Degenerate\r\nFirst Appearance: The New Mutants #98 (February 1991)\r\n\r\nOrigins & History:\r\nA former Canadian Special Forces operative and mercenary, Wade Wilson was diagnosed with terminal cancer. He volunteered for the clandestine Weapon X program, which subjected him to a rogue regenerative healing factor derived from Wolverine. The experiment cured his cancer but left him severely disfigured with a perpetually healing, scarred visage and a severely unstable mental state, a side effect of his healing factor constantly fighting brain damage.\r\n\r\nDefining Traits & Abilities:\r\nPossesses an extreme regenerative healing factor that makes him virtually immortal, capable of regenerating from near disintegration. He is a master assassin and mercenary, proficient in multiple forms of combat and weaponry, with a particular affinity for katanas and firearms. His most famous trait is his "Fourth Wall" awareness; he knows he is a comic book/film character, directly addressing the reader/viewer and commenting on narrative tropes. This meta-awareness is intertwined with a chaotic, irreverent, and hyper-verbal sense of humor used to mask deep psychological pain. He is morally ambiguous, operating as an antihero.\r\n\r\nPersonal Details:\r\nAge: Chronologically born in the 1970s (appears ageless due to healing factor).\r\nFamily: Has a tumultuous relationship with his father, who was abusive. He is married to the supernatural entity Shiklah, Queen of the Monster Metropolis, though their relationship is complicated and often separated. He has a daughter named Eleanor, from a non-romantic genetic legacy, whom he protects fiercely.\r\nKey Relationships: Often a reluctant ally to Cable (Nathan Summers), whom he views as a brother/father figure. Has a frenemy dynamic with Spider-Man and Wolverine. His frequent chauffeur and confidant is the mundane cab driver Dopinder.\r\nBase of Operations: Mobile, but often operates out of a run-down apartment in New York City.\r\nAffiliation: Primarily a loner, but has been a member of X-Force, the Avengers, and the Mercs for Money.\r\n\r\nPsychological Profile: Diagnosed with severe mental illness, including psychosis and manic tendencies, exacerbated by his meta-awareness. His rapid-fire humor is a coping mechanism for trauma, disfigurement, and existential ennui. Despite his violent profession, he adheres to a personal (if flexible) code that often protects innocents and children.', mimetype='text/plain', start_char_idx=0, end_char_idx=2512, metadata_sepe ...
